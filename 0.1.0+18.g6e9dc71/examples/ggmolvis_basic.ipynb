# %% [markdown]
# # Molecular Visualization with GGMolVis
#
# This notebook provides some basic usage examples of the GGMolVis library.
#
# Currently, they are proof of concept examples and are subject to change (and implement) in the future.
#
# Please refer to the Installation guide for instructions on how to install the library.

# %%
import MDAnalysis as mda
from ggmolvis.tests.data import PSF, DCD
from MDAnalysis.analysis.rms import RMSD

import molecularnodes as mn
import numpy as np
import bpy

import ggmolvis
from ggmolvis.ggmolvis import GGMolVis
# Out:
# 2025-03-17 19:27:14.778 | DEBUG    | ggmolvis:<module>:50 - Blend file stored at /var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/ggmolvis.blend
# 2025-03-17 19:27:14.858 | DEBUG    | ggmolvis.ggmolvis:__new__:86 - Creating new GGMolVis

# %%
print(f'ggmolvis version: {ggmolvis.__version__}')
print(f'ggmolvis path: {ggmolvis.__file__}')
print(f'molecularnodes version: {mn.__file__}')
# Out:
# ggmolvis version: 0.1.0+13.gd99edad.dirty
# ggmolvis path: /Users/scottzhuang/git_rego/ggmolvis/ggmolvis/__init__.py
# molecularnodes version: /Users/scottzhuang/git_rego/MolecularNodes/molecularnodes/__init__.py

# %% [markdown]
# ## Trajectory Visualization

# %% [markdown]
# Load the trajectory file by creating a MDAnalysis Universe object.
# Replace `PSF` to your own topology file and `DCD` to your own trajectory file.

# %%
u = mda.Universe(PSF, DCD)
# Out:
# /Applications/Blender.app/Contents/Resources/4.3/python/lib/python3.11/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"

# %% [markdown]
# Initialize the GGMolVis object. It can be thought of as a `Figure` or a canvas for the molecular visualization.

# %%
ggmv = GGMolVis()

# %% [markdown]
# Select molecular entities of interest to be visualized. Refer to: https://docs.mdanalysis.org/stable/documentation_pages/selections.html for the selection syntax.

# %%
residues_ag = u.select_atoms('resid 127 40')
protein_ag = u.select_atoms('protein')

# %% [markdown]
# Here we include our molecules into the `GGMolVis` object by calling the `molecule` method.

# %%
residue_mol = ggmv.molecule(residues_ag)
protein_mol = ggmv.molecule(protein_ag, style='cartoon')
protein_surface_mol = ggmv.molecule(protein_ag, style='surface', material='transparent')

# %% [markdown]
# Render the current frame by calling the `render` method.

# %%
ggmv.render(residue_mol)
# Out:
# Rendering to: /var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmp9bjc9daq.PNG
# Read blend: "/var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/ggmolvis.blend"
# Saved: '/var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmp9bjc9daq.PNG'
# Time: 00:05.06 (Saving: 00:00.07)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x360>

# %% [markdown]
# Render the selected frame by calling the `render(frame)` method.

# %%
ggmv.render(residue_mol, frame=60)
# Out:
# Rendering to: /var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmp9lcewmhk.PNG
# Saved: '/var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmp9lcewmhk.PNG'
# Time: 00:04.38 (Saving: 00:00.01)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x360>

# %% [markdown]
# You can render the whole trajectory by calling the `.render(mode='movie')` method.

# %%
bpy.context.scene.frame_start = 0
bpy.context.scene.frame_end = 60
bpy.context.scene.frame_set(0)

ggmv.render(residue_mol, mode='movie')

# %% [markdown]
# You can change the representation style by calling `set_style` method.

# %%
residue_mol.set_style('ball_and_stick')

# %%
ggmv.render(residue_mol)
# Out:
# Rendering to: /var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmp_38hdvct.PNG
# Saved: '/var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmp_38hdvct.PNG'
# Time: 00:04.34 (Saving: 00:00.01)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x360>

# %% [markdown]
# Each molecule has a unique camera view pointing to the center of the molecule. There is also a global camera view. You can render it by calling `render` without object.

# %%
ggmv.render()
# Out:
# None None None None None (640, 360) None
# Rendering to: /var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmp6szlh2ae.PNG
# Saved: '/var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmp6szlh2ae.PNG'
# Time: 00:02.66 (Saving: 00:00.01)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x360>

# %% [markdown]
# Change focal lens by setting `lens` attribute.

# %%
ggmv.render(protein_mol,lens=50)
# Out:
# 50 None None None None (640, 360) None
# Rendering to: /var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmpykoywk64.PNG
# Saved: '/var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmpykoywk64.PNG'
# Time: 00:03.71 (Saving: 00:00.01)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x360>

# %%
ggmv.render(protein_mol, lens=20)
# Out:
# 20 None None None None (640, 360) None
# Rendering to: /var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmplzrexmpq.PNG
# Saved: '/var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmplzrexmpq.PNG'
# Time: 00:02.79 (Saving: 00:00.01)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x360>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Alternatively, GGMolVis also provides a `visualize` method to `AtomGroup`.

# %%
residues_ag.visualize()
# Out:
# Rendering to: /var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmp_eklymv6.PNG
# Saved: '/var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmp_eklymv6.PNG'
# Time: 00:02.74 (Saving: 00:00.01)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x360>

# %% [markdown]
# ## Geometric feature Visualization

# %% [markdown]
# Visualize simple geometric features, e.g. distance can be done by calling the `distance` method.

# %%
res_1 = residues_ag.residues[0].atoms
res_2 = residues_ag.residues[1].atoms
line = ggmv.distance(res_1, res_2, location=(5,0,0))

# %%
ggmv.render(residue_mol)
# Out:
# Rendering to: /var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmpuglnsger.PNG
# Saved: '/var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmpuglnsger.PNG'
# Time: 00:04.38 (Saving: 00:00.01)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x360>

# %% [markdown]
# ## Analysis Visualization

# %%
rmsd = RMSD(u.select_atoms('name CA'))
rmsd.run()

# %%
vis = rmsd.visualize()
# Out:
# Rendering to: /var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmpq3yby1rz.PNG
# Read blend: "/var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/ggmolvis.blend"
# Saved: '/var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmpq3yby1rz.PNG'
# Time: 00:02.84 (Saving: 00:00.07)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x360>

# %%
ggmv.render(vis, mode='movie')
# Out:
# Rendering to: /var/folders/fn/_k4nj2nd6zv85t7_r3417nb40000gn/T/tmpxd3n_9mr.mp4
# Append frame 1
# Time: 00:02.64 (Saving: 00:00.00)
#
# Append frame 2
# Time: 00:02.53 (Saving: 00:00.00)
#
# Append frame 3
# Time: 00:02.51 (Saving: 00:00.00)
#
# Append frame 4
# Time: 00:02.44 (Saving: 00:00.00)
#
# Append frame 5
# Time: 00:02.33 (Saving: 00:00.00)
#
# Append frame 6
# Time: 00:02.34 (Saving: 00:00.00)
#
# Append frame 7
# Time: 00:02.31 (Saving: 00:00.00)
#
# Append frame 8
# Time: 00:02.30 (Saving: 00:00.00)
#
# Append frame 9
# Time: 00:02.22 (Saving: 00:00.00)
#
# Append frame 10
# Time: 00:02.31 (Saving: 00:00.00)
#
# Append frame 11
# Time: 00:02.17 (Saving: 00:00.00)
#
# Append frame 12
# Time: 00:02.27 (Saving: 00:00.00)
#
# Append frame 13
# Time: 00:02.32 (Saving: 00:00.00)
#
# Append frame 14
# Time: 00:02.33 (Saving: 00:00.00)
#
# Append frame 15
# Time: 00:02.24 (Saving: 00:00.00)
#
# Append frame 16
# Time: 00:02.35 (Saving: 00:00.00)
#
# Append frame 17
# Time: 00:02.44 (Saving: 00:00.00)
#
# Append frame 18
# Time: 00:02.33 (Saving: 00:00.00)
#
# Append frame 19
# Time: 00:02.48 (Saving: 00:00.00)
#
# Append frame 20
# Time: 00:02.35 (Saving: 00:00.00)
#
# Append frame 21
# Time: 00:02.31 (Saving: 00:00.00)
#
# Append frame 22
# Time: 00:02.21 (Saving: 00:00.00)
#
# Append frame 23
# Time: 00:02.19 (Saving: 00:00.00)
#
# Append frame 24
# Time: 00:02.25 (Saving: 00:00.00)
#
# Append frame 25
# Time: 00:02.37 (Saving: 00:00.00)
#
# Append frame 26
# Time: 00:02.35 (Saving: 00:00.00)
#
# Append frame 27
# Time: 00:02.24 (Saving: 00:00.00)
#
# Append frame 28
# Time: 00:02.21 (Saving: 00:00.00)
#
# Append frame 29
# Time: 00:02.35 (Saving: 00:00.00)
#
# Append frame 30
# Time: 00:02.36 (Saving: 00:00.00)
#
# Append frame 31
# Time: 00:02.18 (Saving: 00:00.00)
#
# Append frame 32
# Time: 00:02.20 (Saving: 00:00.00)
#
# Append frame 33
# Time: 00:02.20 (Saving: 00:00.00)
#
# Append frame 34
# Time: 00:02.35 (Saving: 00:00.00)
#
# Append frame 35
# Time: 00:02.52 (Saving: 00:00.00)
#
# Append frame 36
# Time: 00:02.40 (Saving: 00:00.00)
#
# Append frame 37
# Time: 00:02.33 (Saving: 00:00.00)
#
# Append frame 38
# Time: 00:02.16 (Saving: 00:00.00)
#
# Append frame 39
# Time: 00:02.09 (Saving: 00:00.00)
#
# Append frame 40
# Time: 00:02.12 (Saving: 00:00.00)
#
# Append frame 41
# Time: 00:02.11 (Saving: 00:00.00)
#
# Append frame 42
# Time: 00:02.09 (Saving: 00:00.00)
#
# Append frame 43
# Time: 00:02.11 (Saving: 00:00.00)
#
# Append frame 44
# Time: 00:02.08 (Saving: 00:00.00)
#
# Append frame 45
# Time: 00:02.26 (Saving: 00:00.00)
#
# Append frame 46
# Time: 00:02.50 (Saving: 00:00.00)
#
# Append frame 47
# Time: 00:02.23 (Saving: 00:00.01)
#
# Append frame 48
# Time: 00:02.32 (Saving: 00:00.00)
#
# Append frame 49
# Time: 00:02.16 (Saving: 00:00.00)
#
# Append frame 50
# Time: 00:02.13 (Saving: 00:00.00)
#
# Append frame 51
# Time: 00:02.14 (Saving: 00:00.00)
#
# Append frame 52
# Time: 00:02.04 (Saving: 00:00.00)
#
# Append frame 53
# Time: 00:02.15 (Saving: 00:00.00)
#
# Append frame 54
# Time: 00:02.17 (Saving: 00:00.00)
#
# Append frame 55
# Time: 00:02.20 (Saving: 00:00.00)
#
# Append frame 56
# Time: 00:02.21 (Saving: 00:00.00)
#
# Append frame 57
# Time: 00:02.08 (Saving: 00:00.00)
#
# Append frame 58
# Time: 00:02.15 (Saving: 00:00.00)
#
# Append frame 59
# Time: 00:02.04 (Saving: 00:00.00)
#
# Append frame 60
# Time: 00:02.20 (Saving: 00:00.00)
#
# Append frame 61
# Time: 00:02.27 (Saving: 00:00.00)
#
# Append frame 62
# Time: 00:02.15 (Saving: 00:00.00)
#
# Append frame 63
# Time: 00:02.13 (Saving: 00:00.00)
#
# Append frame 64
# Time: 00:02.17 (Saving: 00:00.00)
#
# Append frame 65
# Time: 00:01.83 (Saving: 00:00.00)
#
# Append frame 66
# Time: 00:02.12 (Saving: 00:00.00)
#
# Append frame 67
# Time: 00:02.06 (Saving: 00:00.00)
#
# Append frame 68
# Time: 00:02.14 (Saving: 00:00.00)
#
# Append frame 69
# Time: 00:02.13 (Saving: 00:00.00)
#
# Append frame 70
# Time: 00:01.96 (Saving: 00:00.00)
#
# Append frame 71
# Time: 00:02.30 (Saving: 00:00.00)
#
# Append frame 72
# Time: 00:01.84 (Saving: 00:00.00)
#
# Append frame 73
# Time: 00:01.98 (Saving: 00:00.00)
#
# Append frame 74
# Time: 00:02.22 (Saving: 00:00.00)
#
# Append frame 75
# Time: 00:02.23 (Saving: 00:00.00)
#
# Append frame 76
# Time: 00:02.03 (Saving: 00:00.00)
#
# Append frame 77
# Time: 00:02.19 (Saving: 00:00.00)
#
# Append frame 78
# Time: 00:02.30 (Saving: 00:00.00)
#
# Append frame 79
# Time: 00:02.30 (Saving: 00:00.00)
#
# Append frame 80
# Time: 00:02.19 (Saving: 00:00.00)
#
# Append frame 81
# Time: 00:02.21 (Saving: 00:00.00)
#
# Append frame 82
# Time: 00:02.23 (Saving: 00:00.00)
#
# Append frame 83
# Time: 00:02.21 (Saving: 00:00.00)
#
# Append frame 84
# Time: 00:02.22 (Saving: 00:00.00)
#
# Append frame 85
# Time: 00:01.85 (Saving: 00:00.00)
#
# Append frame 86
# Time: 00:02.15 (Saving: 00:00.00)
#
# Append frame 87
# Time: 00:02.18 (Saving: 00:00.00)
#
# Append frame 88
# Time: 00:02.02 (Saving: 00:00.00)
#
# Append frame 89
# Time: 00:02.19 (Saving: 00:00.00)
#
# Append frame 90
# Time: 00:02.14 (Saving: 00:00.00)
#
# Append frame 91
# Time: 00:02.16 (Saving: 00:00.00)
#
# Append frame 92
# Time: 00:02.22 (Saving: 00:00.00)
#
# Append frame 93
# Time: 00:02.26 (Saving: 00:00.00)
#
# Append frame 94
# Time: 00:02.15 (Saving: 00:00.00)
#
# Append frame 95
# Time: 00:02.18 (Saving: 00:00.00)
#
# Append frame 96
# Time: 00:02.11 (Saving: 00:00.00)
#
# Append frame 97
# Time: 00:01.89 (Saving: 00:00.00)
# Error in bpy.app.handlers.frame_change_post[0]:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/git_rego/MolecularNodes/molecularnodes/handlers.py:54, in update_trajectories(scene)
#      52 if hasattr(traj, "update_with_scene"):
#      53     if traj.update_with_scene:
# ---> 54         traj.set_frame(scene.frame_current)
#      55     else:
#      56         traj.set_frame(traj.frame)
#
# File ~/git_rego/MolecularNodes/molecularnodes/entities/trajectory/trajectory.py:635, in Trajectory.set_frame(self, frame)
#     630 """
#     631 Update the positions, selections and calculations for this trajectory, based on
#     632 frame number of the current scene, not the frame number of the Universe
#     633 """
#     634 self._frame = self.frame_mapper(frame)
# --> 635 self._update_positions(frame)
#     636 self._update_selections()
#     637 self._update_calculations()
#
# File ~/git_rego/MolecularNodes/molecularnodes/entities/trajectory/trajectory.py:717, in Trajectory._update_positions(self, frame)
#     713     self.position = self.position_cache_mean(uframe_current)
#     714 else:
#     715     # otherwise just get the current positions for the relevant frame and set
#     716     # those on the object
# --> 717     self.position = self._position_at_frame(uframe_current)
#
# File ~/git_rego/MolecularNodes/molecularnodes/entities/trajectory/trajectory.py:641, in Trajectory._position_at_frame(self, frame)
#     639 def _position_at_frame(self, frame: int) -> np.ndarray:
#     640     "Return the atom positions at the given universe frame number"
# --> 641     self.uframe = frame
#     642     return self.univ_positions
#
# File ~/git_rego/MolecularNodes/molecularnodes/entities/trajectory/trajectory.py:208, in Trajectory.uframe(self, value)
#     195 """
#     196 Set the current frame number of the linked `Universe.trajectory`.
#     197
#    (...)    205     None
#     206 """
#     207 if self.universe.trajectory.frame != value:
# --> 208     self.universe.trajectory[value]
#
# File /Applications/Blender.app/Contents/Resources/4.3/python/lib/python3.11/site-packages/MDAnalysis/coordinates/base.py:835, in ProtoReader.__getitem__(self, frame)
#     822 """Return the Timestep corresponding to *frame*.
#     823
#     824 If `frame` is a integer then the corresponding frame is
#    (...)    832 *frame* is a 0-based frame index.
#     833 """
#     834 if isinstance(frame, numbers.Integral):
# --> 835     frame = self._apply_limits(frame)
#     836     return self._read_frame_with_aux(frame)
#     837 elif isinstance(frame, (list, np.ndarray)):
#
# File /Applications/Blender.app/Contents/Resources/4.3/python/lib/python3.11/site-packages/MDAnalysis/coordinates/base.py:817, in ProtoReader._apply_limits(self, frame)
#     815     frame += len(self)
#     816 if frame < 0 or frame >= len(self):
# --> 817     raise IndexError("Index {} exceeds length of trajectory ({})."
#     818                      "".format(frame, len(self)))
#     819 return frame
#
# IndexError: Index 98 exceeds length of trajectory (98).
# Append frame 98
# Time: 00:02.08 (Saving: 00:00.00)
